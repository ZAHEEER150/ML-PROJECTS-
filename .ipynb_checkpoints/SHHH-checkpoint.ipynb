# %% [markdown]
# CREATING LABELS FOR CLASSIFICATION

# %%
g='GREEN'
p='PINK'
bk='BLACK'
be='BLUE'
f='FLOWER'
w='WHITE'
n='NAVY'
gry='GREY'
bn='BROWN'

# %% [markdown]
# NUMBER OF DAYS

# %%
import numpy as np
a=np.arange(1,3)

# %% [markdown]
# DAILY COLOUR

# %%
b=[gry,bk]
